# %%
import os
import pandas as pd

walk_path = '/home/pgajo/projects/def-hsajjad/pgajo/Multitask-RFG-torch/results_steps'
df_aggregate = pd.DataFrame(columns=['metric', 'val_prec', 'val_recall', 'val_f1', 'test_prec', 'test_recall', 'test_f1', 'setting', 'seed'])
for root, dirs, files in os.walk(walk_path):
    for F in files:
        entry = {}
        filename = os.path.join(root, F)
        if filename.endswith('config.json'):
            flags = filename.split('/')
            df = pd.read_json(filename)

            # print(df.columns)
            df = df.drop(['config'], axis = 1)
            df = df.dropna()
            df = df.reset_index()
            df = df.rename(columns={'index': 'metric'})
            # display(df)
            
            df['val_prec'] = df['val_results'].apply(lambda x: x['P'])
            df['val_recall'] = df['val_results'].apply(lambda x: x['R'])
            df['val_f1'] = df['val_results'].apply(lambda x: x['F1'])
            df['test_prec'] = df['test_results'].apply(lambda x: x['P'])
            df['test_recall'] = df['test_results'].apply(lambda x: x['R'])
            df['test_f1'] = df['test_results'].apply(lambda x: x['F1'])
            df['setting'] = flags[-3]
            df['seed'] = flags[-2].split('_')[-1]
            df = df.drop(['val_results', 'test_results'], axis = 1)
            
            # df = df.reset_index()
            df_aggregate = pd.concat([df_aggregate, df])
display(df_aggregate)
df_group = df_aggregate.groupby(['metric', 'setting'])['test_f1']
df_group.mean()
# Out:
# /tmp/ipykernel_1020295/66636369.py:32: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_aggregate = pd.concat([df_aggregate, df])
#                       metric  val_prec  val_recall  val_f1  test_prec  \
# 0             tagger_results    0.6966      0.6940  0.6953     0.6378
# 1     parser_labeled_results    0.6648      0.6638  0.6643     0.6309
# 2   parser_unlabeled_results    0.7770      0.7753  0.7762     0.8035
# 0             tagger_results    0.7015      0.6935  0.6975     0.6465
# 1     parser_labeled_results    0.6763      0.6624  0.6693     0.6348
# ..                       ...       ...         ...     ...        ...
# 1     parser_labeled_results    0.6796      0.6709  0.6752     0.6394
# 2   parser_unlabeled_results    0.7960      0.7853  0.7906     0.8106
# 0             tagger_results    0.6942      0.7029  0.6985     0.6436
# 1     parser_labeled_results    0.6766      0.6752  0.6759     0.6325
# 2   parser_unlabeled_results    0.7889      0.7867  0.7878     0.7978
#
#     test_recall  test_f1                                setting seed
# 0        0.6433   0.6405   aug_100_random_keep_111_k_5-0-0_2000    2
# 1        0.6313   0.6311   aug_100_random_keep_111_k_5-0-0_2000    2
# 2        0.8041   0.8038   aug_100_random_keep_111_k_5-0-0_2000    2
# 0        0.6459   0.6462   aug_100_random_keep_111_k_5-0-0_2000    3
# 1        0.6231   0.6289   aug_100_random_keep_111_k_5-0-0_2000    3
# ..          ...      ...                                    ...  ...
# 1        0.6429   0.6411  aug_100_permute_keep_111_k_1-0-0_2000    3
# 2        0.8150   0.8128  aug_100_permute_keep_111_k_1-0-0_2000    3
# 0        0.6505   0.6470  aug_100_permute_keep_111_k_1-0-0_2000    0
# 1        0.6299   0.6312  aug_100_permute_keep_111_k_1-0-0_2000    0
# 2        0.7946   0.7962  aug_100_permute_keep_111_k_1-0-0_2000    0
#
# [99 rows x 9 columns]
# metric                    setting
# parser_labeled_results    aug_000_none_keep_111_k_0-0-0_2000       0.640920
#                           aug_100_hybrid_keep_111_k_1-0-0_2000     0.641140
#                           aug_100_hybrid_keep_111_k_5-0-0_2000     0.635160
#                           aug_100_permute_keep_111_k_1-0-0_2000    0.640320
#                           aug_100_permute_keep_111_k_5-0-0_2000    0.641960
#                           aug_100_random_keep_111_k_1-0-0_2000     0.636050
#                           aug_100_random_keep_111_k_5-0-0_2000     0.636600
# parser_unlabeled_results  aug_000_none_keep_111_k_0-0-0_2000       0.805900
#                           aug_100_hybrid_keep_111_k_1-0-0_2000     0.809360
#                           aug_100_hybrid_keep_111_k_5-0-0_2000     0.803180
#                           aug_100_permute_keep_111_k_1-0-0_2000    0.806240
#                           aug_100_permute_keep_111_k_5-0-0_2000    0.809280
#                           aug_100_random_keep_111_k_1-0-0_2000     0.804525
#                           aug_100_random_keep_111_k_5-0-0_2000     0.805525
# tagger_results            aug_000_none_keep_111_k_0-0-0_2000       0.644320
#                           aug_100_hybrid_keep_111_k_1-0-0_2000     0.645060
#                           aug_100_hybrid_keep_111_k_5-0-0_2000     0.645360
#                           aug_100_permute_keep_111_k_1-0-0_2000    0.646160
#                           aug_100_permute_keep_111_k_5-0-0_2000    0.643460
#                           aug_100_random_keep_111_k_1-0-0_2000     0.643825
#                           aug_100_random_keep_111_k_5-0-0_2000     0.644425
# Name: test_f1, dtype: float64
