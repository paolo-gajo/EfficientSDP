# %%
import os
import pandas as pd

walk_path = '/home/pgajo/Multitask-RFG-torch/results_steps/freeze_encoder_1'
df_aggregate = pd.DataFrame(columns=['metric', 'val_prec', 'val_recall', 'val_f1', 'test_prec', 'test_recall', 'test_f1', 'setting', 'seed'])
for root, dirs, files in os.walk(walk_path):
    for F in files:
        entry = {}
        filename = os.path.join(root, F)
        if filename.endswith('config.json'):
            flags = filename.split('/')
            df = pd.read_json(filename)

            # print(df.columns)
            df = df.drop(['config'], axis = 1)
            df = df.dropna()
            df = df.reset_index()
            df = df.rename(columns={'index': 'metric'})
            # display(df)
            
            df['val_prec'] = df['val_results'].apply(lambda x: x['P'])
            df['val_recall'] = df['val_results'].apply(lambda x: x['R'])
            df['val_f1'] = df['val_results'].apply(lambda x: x['F1'])
            df['test_prec'] = df['test_results'].apply(lambda x: x['P'])
            df['test_recall'] = df['test_results'].apply(lambda x: x['R'])
            df['test_f1'] = df['test_results'].apply(lambda x: x['F1'])
            df['setting'] = '-'.join(flags[5:-3])#.split('-')[-1]
            df['seed'] = flags[-2].split('_')[-1]
            df = df.drop(['val_results', 'test_results'], axis = 1)
            
            # df = df.reset_index()
            df_aggregate = pd.concat([df_aggregate, df])
display(df_aggregate)
df_group = df_aggregate.groupby(['metric', 'setting'])['test_f1']
df_group.mean()
# Out:
# /tmp/ipykernel_1225535/2959354910.py:32: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_aggregate = pd.concat([df_aggregate, df])
#                      metric  val_prec  val_recall  val_f1  test_prec  \
# 0            tagger_results    0.6955      0.6774  0.6863     0.6199
# 1    parser_labeled_results    0.6492      0.6322  0.6406     0.6270
# 2  parser_unlabeled_results    0.7729      0.7527  0.7627     0.7915
# 0            tagger_results    0.6879      0.6836  0.6858     0.6251
# 1    parser_labeled_results    0.6449      0.6513  0.6481     0.6228
# 2  parser_unlabeled_results    0.7642      0.7718  0.7680     0.7807
# 0            tagger_results    0.5836      0.5751  0.5793     0.5603
# 1    parser_labeled_results    0.5977      0.5939  0.5958     0.5730
# 2  parser_unlabeled_results    0.7104      0.7059  0.7081     0.7183
# 0            tagger_results    0.7097      0.6997  0.7047     0.6461
# 1    parser_labeled_results    0.6605      0.6329  0.6464     0.6264
# 2  parser_unlabeled_results    0.7840      0.7512  0.7673     0.7903
# 0            tagger_results    0.7187      0.6888  0.7034     0.6573
# 1    parser_labeled_results    0.6480      0.6300  0.6389     0.6188
# 2  parser_unlabeled_results    0.7704      0.7491  0.7596     0.7769
# 0            tagger_results    0.6957      0.6878  0.6917     0.6340
# 1    parser_labeled_results    0.5452      0.3806  0.4482     0.5166
# 2  parser_unlabeled_results    0.6355      0.4437  0.5225     0.6199
# 0            tagger_results    0.6954      0.6868  0.6911     0.6329
# 1    parser_labeled_results    0.5455      0.5436  0.5446     0.5049
# 2  parser_unlabeled_results    0.6522      0.6499  0.6510     0.6543
# 0            tagger_results    0.6964      0.6899  0.6931     0.6336
# 1    parser_labeled_results    0.6033      0.5897  0.5964     0.5806
# 2  parser_unlabeled_results    0.7099      0.6938  0.7018     0.7209
#
#    test_recall  test_f1                                            setting  \
# 0       0.6168   0.6183  freeze_encoder_1-arc_predattn-stepmask_0-gnn_0...
# 1       0.6095   0.6181  freeze_encoder_1-arc_predattn-stepmask_0-gnn_0...
# 2       0.7694   0.7803  freeze_encoder_1-arc_predattn-stepmask_0-gnn_0...
# 0       0.6270   0.6260  freeze_encoder_1-arc_predattn-stepmask_0-gnn_0...
# 1       0.6279   0.6253  freeze_encoder_1-arc_predattn-stepmask_0-gnn_0...
# 2       0.7871   0.7839  freeze_encoder_1-arc_predattn-stepmask_0-gnn_0...
# 0       0.5600   0.5602  freeze_encoder_1-arc_predattn-stepmask_0-gnn_0...
# 1       0.5741   0.5736  freeze_encoder_1-arc_predattn-stepmask_0-gnn_0...
# 2       0.7197   0.7190  freeze_encoder_1-arc_predattn-stepmask_0-gnn_0...
# 0       0.6464   0.6462  freeze_encoder_1-arc_predattn-stepmask_0-gnn_0...
# 1       0.6034   0.6147  freeze_encoder_1-arc_predattn-stepmask_0-gnn_0...
# 2       0.7612   0.7755  freeze_encoder_1-arc_predattn-stepmask_0-gnn_0...
# 0       0.6428   0.6500  freeze_encoder_1-arc_predattn-stepmask_0-gnn_0...
# 1       0.6095   0.6141  freeze_encoder_1-arc_predattn-stepmask_0-gnn_0...
# 2       0.7653   0.7711  freeze_encoder_1-arc_predattn-stepmask_0-gnn_0...
# 0       0.6357   0.6349  freeze_encoder_1-arc_predattn-stepmask_0-gnn_0...
# 1       0.3912   0.4452  freeze_encoder_1-arc_predattn-stepmask_0-gnn_0...
# 2       0.4694   0.5343  freeze_encoder_1-arc_predattn-stepmask_0-gnn_0...
# 0       0.6362   0.6346  freeze_encoder_1-arc_predattn-stepmask_0-gnn_0...
# 1       0.4918   0.4983  freeze_encoder_1-arc_predattn-stepmask_0-gnn_0...
# 2       0.6374   0.6458  freeze_encoder_1-arc_predattn-stepmask_0-gnn_0...
# 0       0.6372   0.6354  freeze_encoder_1-arc_predattn-stepmask_0-gnn_0...
# 1       0.5660   0.5732  freeze_encoder_1-arc_predattn-stepmask_0-gnn_0...
# 2       0.7027   0.7117  freeze_encoder_1-arc_predattn-stepmask_0-gnn_0...
#
#   seed
# 0   27
# 1   27
# 2   27
# 0   27
# 1   27
# 2   27
# 0   27
# 1   27
# 2   27
# 0   27
# 1   27
# 2   27
# 0   27
# 1   27
# 2   27
# 0   27
# 1   27
# 2   27
# 0   27
# 1   27
# 2   27
# 0   27
# 1   27
# 2   27
# metric                    setting
# parser_labeled_results    freeze_encoder_1-arc_predattn-stepmask_0-gnn_0-bpos_1-tagemb_0-lstm_0-laplacian_pe_-use_abs_step_embeddings_0-data=yamakata-parser_type_gnn_1    0.5732
#                           freeze_encoder_1-arc_predattn-stepmask_0-gnn_0-bpos_1-tagemb_0-lstm_0-laplacian_pe_-use_abs_step_embeddings_0-data=yamakata-parser_type_gnn_2    0.4983
#                           freeze_encoder_1-arc_predattn-stepmask_0-gnn_0-bpos_1-tagemb_0-lstm_0-laplacian_pe_-use_abs_step_embeddings_0-data=yamakata-parser_type_mtrfg    0.4452
#                           freeze_encoder_1-arc_predattn-stepmask_0-gnn_0-bpos_1-tagemb_0-lstm_1-laplacian_pe_-use_abs_step_embeddings_0-data=yamakata-parser_type_gnn_1    0.6141
#                           freeze_encoder_1-arc_predattn-stepmask_0-gnn_0-bpos_1-tagemb_0-lstm_1-laplacian_pe_-use_abs_step_embeddings_0-data=yamakata-parser_type_mtrfg    0.6147
#                           freeze_encoder_1-arc_predattn-stepmask_0-gnn_0-bpos_1-tagemb_1-lstm_0-laplacian_pe_-use_abs_step_embeddings_0-data=yamakata-parser_type_gnn_1    0.5736
#                           freeze_encoder_1-arc_predattn-stepmask_0-gnn_0-bpos_1-tagemb_1-lstm_1-laplacian_pe_-use_abs_step_embeddings_0-data=yamakata-parser_type_gnn_1    0.6253
#                           freeze_encoder_1-arc_predattn-stepmask_0-gnn_0-bpos_1-tagemb_1-lstm_1-laplacian_pe_-use_abs_step_embeddings_0-data=yamakata-parser_type_mtrfg    0.6181
# parser_unlabeled_results  freeze_encoder_1-arc_predattn-stepmask_0-gnn_0-bpos_1-tagemb_0-lstm_0-laplacian_pe_-use_abs_step_embeddings_0-data=yamakata-parser_type_gnn_1    0.7117
#                           freeze_encoder_1-arc_predattn-stepmask_0-gnn_0-bpos_1-tagemb_0-lstm_0-laplacian_pe_-use_abs_step_embeddings_0-data=yamakata-parser_type_gnn_2    0.6458
#                           freeze_encoder_1-arc_predattn-stepmask_0-gnn_0-bpos_1-tagemb_0-lstm_0-laplacian_pe_-use_abs_step_embeddings_0-data=yamakata-parser_type_mtrfg    0.5343
#                           freeze_encoder_1-arc_predattn-stepmask_0-gnn_0-bpos_1-tagemb_0-lstm_1-laplacian_pe_-use_abs_step_embeddings_0-data=yamakata-parser_type_gnn_1    0.7711
#                           freeze_encoder_1-arc_predattn-stepmask_0-gnn_0-bpos_1-tagemb_0-lstm_1-laplacian_pe_-use_abs_step_embeddings_0-data=yamakata-parser_type_mtrfg    0.7755
#                           freeze_encoder_1-arc_predattn-stepmask_0-gnn_0-bpos_1-tagemb_1-lstm_0-laplacian_pe_-use_abs_step_embeddings_0-data=yamakata-parser_type_gnn_1    0.7190
#                           freeze_encoder_1-arc_predattn-stepmask_0-gnn_0-bpos_1-tagemb_1-lstm_1-laplacian_pe_-use_abs_step_embeddings_0-data=yamakata-parser_type_gnn_1    0.7839
#                           freeze_encoder_1-arc_predattn-stepmask_0-gnn_0-bpos_1-tagemb_1-lstm_1-laplacian_pe_-use_abs_step_embeddings_0-data=yamakata-parser_type_mtrfg    0.7803
# tagger_results            freeze_encoder_1-arc_predattn-stepmask_0-gnn_0-bpos_1-tagemb_0-lstm_0-laplacian_pe_-use_abs_step_embeddings_0-data=yamakata-parser_type_gnn_1    0.6354
#                           freeze_encoder_1-arc_predattn-stepmask_0-gnn_0-bpos_1-tagemb_0-lstm_0-laplacian_pe_-use_abs_step_embeddings_0-data=yamakata-parser_type_gnn_2    0.6346
#                           freeze_encoder_1-arc_predattn-stepmask_0-gnn_0-bpos_1-tagemb_0-lstm_0-laplacian_pe_-use_abs_step_embeddings_0-data=yamakata-parser_type_mtrfg    0.6349
#                           freeze_encoder_1-arc_predattn-stepmask_0-gnn_0-bpos_1-tagemb_0-lstm_1-laplacian_pe_-use_abs_step_embeddings_0-data=yamakata-parser_type_gnn_1    0.6500
#                           freeze_encoder_1-arc_predattn-stepmask_0-gnn_0-bpos_1-tagemb_0-lstm_1-laplacian_pe_-use_abs_step_embeddings_0-data=yamakata-parser_type_mtrfg    0.6462
#                           freeze_encoder_1-arc_predattn-stepmask_0-gnn_0-bpos_1-tagemb_1-lstm_0-laplacian_pe_-use_abs_step_embeddings_0-data=yamakata-parser_type_gnn_1    0.5602
#                           freeze_encoder_1-arc_predattn-stepmask_0-gnn_0-bpos_1-tagemb_1-lstm_1-laplacian_pe_-use_abs_step_embeddings_0-data=yamakata-parser_type_gnn_1    0.6260
#                           freeze_encoder_1-arc_predattn-stepmask_0-gnn_0-bpos_1-tagemb_1-lstm_1-laplacian_pe_-use_abs_step_embeddings_0-data=yamakata-parser_type_mtrfg    0.6183
# Name: test_f1, dtype: float64
