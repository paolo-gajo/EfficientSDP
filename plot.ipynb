# %%
gnn_from_start_list = [{'tagger_results': {'P': 0.9108, 'R': 0.9108, 'F1': 0.9108, 'acc': 0.9108}, 'parser_labeled_results': {'P': 0.6356, 'R': 0.635, 'F1': 0.6353, 'acc': 0.635}, 'parser_unlabeled_results': {'P': 0.6842, 'R': 0.6842, 'F1': 0.6842, 'acc': 0.6842}, 'uas_las_results': {'uas': 0.6737498678507242, 'las': 0.6349508404693942}, 'epoch': None, 'steps': 500}, {'tagger_results': {'P': 0.9255, 'R': 0.9255, 'F1': 0.9255, 'acc': 0.9255}, 'parser_labeled_results': {'P': 0.6749, 'R': 0.6778, 'F1': 0.6764, 'acc': 0.6778}, 'parser_unlabeled_results': {'P': 0.7228, 'R': 0.7228, 'F1': 0.7228, 'acc': 0.7228}, 'uas_las_results': {'uas': 0.7153504598794799, 'las': 0.6778200655460408}, 'epoch': None, 'steps': 1000}, {'tagger_results': {'P': 0.9336, 'R': 0.9336, 'F1': 0.9336, 'acc': 0.9336}, 'parser_labeled_results': {'P': 0.7061, 'R': 0.7034, 'F1': 0.7047, 'acc': 0.7034}, 'parser_unlabeled_results': {'P': 0.7474, 'R': 0.7474, 'F1': 0.7474, 'acc': 0.7474}, 'uas_las_results': {'uas': 0.7390316101067766, 'las': 0.7034041653451739}, 'epoch': None, 'steps': 1500}, {'tagger_results': {'P': 0.9364, 'R': 0.9364, 'F1': 0.9364, 'acc': 0.9364}, 'parser_labeled_results': {'P': 0.7141, 'R': 0.7065, 'F1': 0.7102, 'acc': 0.7065}, 'parser_unlabeled_results': {'P': 0.7484, 'R': 0.7484, 'F1': 0.7484, 'acc': 0.7484}, 'uas_las_results': {'uas': 0.7392959086584205, 'las': 0.7064700285442436}, 'epoch': None, 'steps': 2000}, {'tagger_results': {'P': 0.9395, 'R': 0.9395, 'F1': 0.9395, 'acc': 0.9395}, 'parser_labeled_results': {'P': 0.7243, 'R': 0.7233, 'F1': 0.7238, 'acc': 0.7233}, 'parser_unlabeled_results': {'P': 0.7655, 'R': 0.7655, 'F1': 0.7655, 'acc': 0.7655}, 'uas_las_results': {'uas': 0.7577439475631673, 'las': 0.7233322761391268}, 'epoch': None, 'steps': 2500}, {'tagger_results': {'P': 0.9392, 'R': 0.9392, 'F1': 0.9392, 'acc': 0.9392}, 'parser_labeled_results': {'P': 0.7337, 'R': 0.7334, 'F1': 0.7336, 'acc': 0.7334}, 'parser_unlabeled_results': {'P': 0.7716, 'R': 0.7716, 'F1': 0.7716, 'acc': 0.7716}, 'uas_las_results': {'uas': 0.7641399725129506, 'las': 0.7334284808119251}, 'epoch': None, 'steps': 3000}, {'tagger_results': {'P': 0.9413, 'R': 0.9413, 'F1': 0.9413, 'acc': 0.9413}, 'parser_labeled_results': {'P': 0.7462, 'R': 0.7421, 'F1': 0.7442, 'acc': 0.7421}, 'parser_unlabeled_results': {'P': 0.782, 'R': 0.782, 'F1': 0.782, 'acc': 0.782}, 'uas_las_results': {'uas': 0.7747119145787081, 'las': 0.7420974733058463}, 'epoch': None, 'steps': 3500}, {'tagger_results': {'P': 0.9413, 'R': 0.9413, 'F1': 0.9413, 'acc': 0.9413}, 'parser_labeled_results': {'P': 0.7578, 'R': 0.7565, 'F1': 0.7572, 'acc': 0.7565}, 'parser_unlabeled_results': {'P': 0.7941, 'R': 0.7941, 'F1': 0.7941, 'acc': 0.7941}, 'uas_las_results': {'uas': 0.7872396659266307, 'las': 0.7564753145152765}, 'epoch': None, 'steps': 4000}, {'tagger_results': {'P': 0.9419, 'R': 0.9419, 'F1': 0.9419, 'acc': 0.9419}, 'parser_labeled_results': {'P': 0.7568, 'R': 0.7566, 'F1': 0.7567, 'acc': 0.7566}, 'parser_unlabeled_results': {'P': 0.7985, 'R': 0.7985, 'F1': 0.7985, 'acc': 0.7985}, 'uas_las_results': {'uas': 0.7922613384078655, 'las': 0.756581033935934}, 'epoch': None, 'steps': 4500}, {'tagger_results': {'P': 0.9422, 'R': 0.9422, 'F1': 0.9422, 'acc': 0.9422}, 'parser_labeled_results': {'P': 0.7518, 'R': 0.753, 'F1': 0.7524, 'acc': 0.753}, 'parser_unlabeled_results': {'P': 0.7927, 'R': 0.7927, 'F1': 0.7927, 'acc': 0.7927}, 'uas_las_results': {'uas': 0.7861296120097262, 'las': 0.7530394333439053}, 'epoch': None, 'steps': 5000}, {'tagger_results': {'P': 0.9412, 'R': 0.9412, 'F1': 0.9412, 'acc': 0.9412}, 'parser_labeled_results': {'P': 0.7665, 'R': 0.7662, 'F1': 0.7664, 'acc': 0.7662}, 'parser_unlabeled_results': {'P': 0.8046, 'R': 0.8046, 'F1': 0.8046, 'acc': 0.8046}, 'uas_las_results': {'uas': 0.7982873453853473, 'las': 0.7662015012157734}, 'epoch': None, 'steps': 5500}, {'tagger_results': {'P': 0.9424, 'R': 0.9424, 'F1': 0.9424, 'acc': 0.9424}, 'parser_labeled_results': {'P': 0.7673, 'R': 0.7686, 'F1': 0.7679, 'acc': 0.7686}, 'parser_unlabeled_results': {'P': 0.8069, 'R': 0.8069, 'F1': 0.8069, 'acc': 0.8069}, 'uas_las_results': {'uas': 0.8007717517708003, 'las': 0.7685801881805687}, 'epoch': None, 'steps': 6000}, {'tagger_results': {'P': 0.9433, 'R': 0.9433, 'F1': 0.9433, 'acc': 0.9433}, 'parser_labeled_results': {'P': 0.7697, 'R': 0.7669, 'F1': 0.7683, 'acc': 0.7669}, 'parser_unlabeled_results': {'P': 0.8044, 'R': 0.8044, 'F1': 0.8044, 'acc': 0.8044}, 'uas_las_results': {'uas': 0.797600169151073, 'las': 0.7669415371603764}, 'epoch': None, 'steps': 6500}, {'tagger_results': {'P': 0.944, 'R': 0.944, 'F1': 0.944, 'acc': 0.944}, 'parser_labeled_results': {'P': 0.7707, 'R': 0.7709, 'F1': 0.7708, 'acc': 0.7709}, 'parser_unlabeled_results': {'P': 0.8092, 'R': 0.8092, 'F1': 0.8092, 'acc': 0.8092}, 'uas_las_results': {'uas': 0.8028861401839518, 'las': 0.7708531557247066}, 'epoch': None, 'steps': 7000}]

# %%
import pandas as pd
import matplotlib.pyplot as plt

filename_gnn = './results_usegnn_1000/freeze_encoder_1/arc_predattn/tagger_rnn_0/parser_rnn_0_lstm_l0_h400/data=scidtb/parser_type_gat_unbatched_3_mlp_500/arc_norm_1/use_lora_0/tag_embedding_type_linear/bert-base-uncased_2025-05-23--13:05:55_seed_0/test_results_series.json'
filename_baseline = './results_usegnn_1000/freeze_encoder_1/arc_predattn/tagger_rnn_0/parser_rnn_0_lstm_l0_h400/data=scidtb/parser_type_gat_unbatched_0_mlp_500/arc_norm_1/use_lora_0/tag_embedding_type_linear/bert-base-uncased_2025-05-23--14:42:24_seed_0/test_results_series.json'
df_gnn = pd.read_json(filename_gnn)
df_gnn_from_start = pd.DataFrame(gnn_from_start_list)
f1_gnn = [el['F1'] for el in df_gnn['parser_labeled_results']]
f1_gnn_from_start = [el['F1'] for el in df_gnn_from_start['parser_labeled_results']]
df_baseline = pd.read_json(filename_baseline)
f1_baseline = [el['F1'] for el in df_baseline['parser_labeled_results']]
plt.plot(f1_gnn, label = 'gnn')
plt.plot(f1_gnn_from_start, label = 'gnn_from_start')
plt.plot(f1_baseline, label = 'baseline')
plt.legend()
plt.show()
